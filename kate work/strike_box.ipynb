# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms

import json
import cv2
import numpy as np

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(device)
# Out:
# cuda

# %% [markdown]
# ## Baseball Detection Model

# %%
from ultralytics import YOLO

model = YOLO("../runs/detect/train13/weights/best.pt")
# results = model.predict(source="baseball-detection-2-4/baseball-detection-2-4/test/images/0eb9ef3c-255_jpg.rf.a9da7151055bf3395bedbdc72c61c4e3.jpg", task="detect", save=True)
results = model.predict("../kate work/media/shohei_pitch(14).png", task="detect", save=True)
# Out:
# image 1/1 /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/media/shohei_pitch(14).png: 320x544 (no detections), 14.7ms
# Speed: 1.9ms preprocess, 14.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 544)
# Results saved to runs/detect/predict3

# %% [markdown]
# ## Batter and Home Plate Model Predict Image

# %%
from ultralytics import YOLO

model = YOLO("../nicks_work/runs/detect/train12/weights/best.pt")
# results = model.predict(source="baseball-detection-2-4/baseball-detection-2-4/test/images/0eb9ef3c-255_jpg.rf.a9da7151055bf3395bedbdc72c61c4e3.jpg", task="detect", save=True)
results = model.predict("../kate work/media/shohei_pitch(14).png", task="detect", save=True)
# Out:
# image 1/1 /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/media/shohei_pitch(14).png: 320x544 1 batter, 12.6ms
# Speed: 2.3ms preprocess, 12.6ms inference, 446.1ms postprocess per image at shape (1, 3, 320, 544)
# Results saved to runs/detect/predict2

# %% [markdown]
# ## Batter and Home Plate Model Predict Video

# %%
from ultralytics import YOLO, settings

model = YOLO("../nicks_work/runs/detect/train12/weights/best.pt")

result = model.track("../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4",conf=0.2, save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 10.3ms
# video 1/1 (frame 2/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 9.3ms
# video 1/1 (frame 3/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 9.6ms
# video 1/1 (frame 4/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 9.5ms
# video 1/1 (frame 5/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 9.6ms
# video 1/1 (frame 6/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 9.6ms
# video 1/1 (frame 7/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 10.2ms
# video 1/1 (frame 8/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 9.7ms
# video 1/1 (frame 9/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 8.7ms
# video 1/1 (frame 10/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 10.7ms
# video 1/1 (frame 11/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 8.8ms
# video 1/1 (frame 12/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 8.9ms
# video 1/1 (frame 13/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 9.6ms
# video 1/1 (frame 14/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 9.5ms
# video 1/1 (frame 15/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 9.1ms
# video 1/1 (frame 16/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 10.3ms
# video 1/1 (frame 17/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 10.1ms
# video 1/1 (frame 18/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 10.2ms
# video 1/1 (frame 19/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 9.4ms
# video 1/1 (frame 20/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 10.0ms
# video 1/1 (frame 21/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 1 home plate, 9.8ms
# video 1/1 (frame 22/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 1 home plate, 9.6ms
# video 1/1 (frame 23/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 2 home plates, 10.1ms
# video 1/1 (frame 24/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 2 home plates, 10.1ms
# video 1/1 (frame 25/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 2 home plates, 9.0ms
# video 1/1 (frame 26/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 2 home plates, 9.7ms
# video 1/1 (frame 27/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 2 home plates, 9.1ms
# video 1/1 (frame 28/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 2 home plates, 14.7ms
# video 1/1 (frame 29/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 2 home plates, 9.2ms
# video 1/1 (frame 30/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 2 home plates, 9.2ms
# video 1/1 (frame 31/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 2 home plates, 9.8ms
# video 1/1 (frame 32/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 10.0ms
# video 1/1 (frame 33/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 9.6ms
# video 1/1 (frame 34/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 1 home plate, 9.7ms
# video 1/1 (frame 35/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 2 home plates, 9.9ms
# video 1/1 (frame 36/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 2 batters, 2 home plates, 9.3ms
# video 1/1 (frame 37/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 2 home plates, 9.1ms
# video 1/1 (frame 38/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 2 home plates, 9.1ms
# video 1/1 (frame 39/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 2 home plates, 9.3ms
# video 1/1 (frame 40/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 2 home plates, 9.0ms
# video 1/1 (frame 41/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 2 home plates, 9.8ms
# video 1/1 (frame 42/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 2 home plates, 9.2ms
# video 1/1 (frame 43/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 2 home plates, 8.8ms
# video 1/1 (frame 44/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 2 home plates, 9.2ms
# video 1/1 (frame 45/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 2 home plates, 9.1ms
# video 1/1 (frame 46/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 2 home plates, 9.3ms
# video 1/1 (frame 47/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 1 home plate, 9.3ms
# video 1/1 (frame 48/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 1 home plate, 9.4ms
# video 1/1 (frame 49/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 1 home plate, 10.7ms
# video 1/1 (frame 50/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 2 home plates, 11.2ms
# video 1/1 (frame 51/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 2 home plates, 9.5ms
# video 1/1 (frame 52/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 2 home plates, 9.5ms
# video 1/1 (frame 53/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 1 home plate, 10.0ms
# video 1/1 (frame 54/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 2 home plates, 9.1ms
# video 1/1 (frame 55/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 1 home plate, 9.0ms
# video 1/1 (frame 56/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 1 home plate, 9.3ms
# video 1/1 (frame 57/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 1 home plate, 9.4ms
# video 1/1 (frame 58/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 1 home plate, 12.3ms
# video 1/1 (frame 59/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 1 home plate, 9.4ms
# video 1/1 (frame 60/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 1 home plate, 9.3ms
# video 1/1 (frame 61/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 9.5ms
# video 1/1 (frame 62/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 1 home plate, 8.8ms
# video 1/1 (frame 63/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 1 home plate, 9.0ms
# video 1/1 (frame 64/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 8.9ms
# video 1/1 (frame 65/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 8.8ms
# video 1/1 (frame 66/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 9.0ms
# video 1/1 (frame 67/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 9.3ms
# video 1/1 (frame 68/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 9.2ms
# video 1/1 (frame 69/69) /home/kmvu/private/AI-Pitch-Recognition/kate work/../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4: 320x544 1 batter, 9.1ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 544)
# Results saved to runs/detect/track2

# %%
# !brew install opencv
# !pip install opencv-python --upgrade
# Out:
# /bin/bash: line 1: brew: command not found
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.11/site-packages (4.10.0.84)
# Collecting opencv-python
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /opt/conda/lib/python3.11/site-packages (from opencv-python) (1.26.4)
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 20.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.11.0.86

# %% [markdown]
# ## Predict Strike Zone

# %%
import cv2
import torch
from ultralytics import YOLO

# Load trained models
batter_homeplate_model = YOLO("../nicks_work/runs/detect/train12/weights/best.pt")  # Detects batter & home plate
baseball_model = YOLO("../runs/detect/train13/weights/best.pt")  # Detects baseball

# Load input video
video_path = "../kate work/strike_videos/All of Shohei Ohtani's 2022 Strikeouts 720 (14).mp4"
cap = cv2.VideoCapture(video_path)

# Get video properties
fps = int(cap.get(cv2.CAP_PROP_FPS))
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define VideoWriter to save output video
output_path = "output.mp4"
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

frame_count = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame_count += 1  # Track frame count

    # Run detection on batter & home plate
    batter_results = batter_homeplate_model(frame)[0]
    baseball_results = baseball_model(frame)[0]

    batter_bbox, plate_bbox, ball_bbox = None, None, None

    # Debugging: Print detection results
    # print(f"Frame {frame_count}:")
    # print(f"Batter & Home Plate Detections: {batter_results}")
    # print(f"Baseball Detections: {baseball_results}")

    # Extract batter & home plate bounding boxes
    for r in batter_results.boxes.data:  # Access detection results correctly
        class_id = int(r[-1])  # Class ID is the last value
        conf = r[-2]  # Confidence score
        if conf < 0.3:  # Ignore low-confidence detections
            continue
        if class_id == 0:  # Batter
            batter_bbox = r[:4].tolist()
        elif class_id == 1:  # Home Plate
            plate_bbox = r[:4].tolist()

    # Extract baseball bounding box
    for r in baseball_results.boxes.data:
        conf = r[-2]
        if conf < 0.3:  # Ignore low-confidence detections
            continue
        if int(r[-1]) == 0:  # Baseball
            ball_bbox = r[:4].tolist()

    # Draw detected objects
    if batter_bbox:
        cv2.rectangle(frame, (int(batter_bbox[0]), int(batter_bbox[1])),
                      (int(batter_bbox[2]), int(batter_bbox[3])), (255, 255, 0), 2)  # Yellow for Batter

    if plate_bbox:
        cv2.rectangle(frame, (int(plate_bbox[0]), int(plate_bbox[1])),
                      (int(plate_bbox[2]), int(plate_bbox[3])), (255, 0, 255), 2)  # Purple for Home Plate

    if ball_bbox:
        ball_center_x = (ball_bbox[0] + ball_bbox[2]) / 2
        ball_center_y = (ball_bbox[1] + ball_bbox[3]) / 2
        cv2.circle(frame, (int(ball_center_x), int(ball_center_y)), 5, (0, 255, 0), -1)  # Green for Ball

    # Compute Strike Zone if batter & home plate are detected
    # Compute Strike Zone if batter & home plate are detected
    if batter_bbox and plate_bbox:
        batter_top = batter_bbox[1]
        batter_bottom = batter_bbox[3]

    # Make strike zone smaller
        strike_zone_top = batter_top + (batter_bottom - batter_top) * 0.3  # Change from 0.2 to 0.3
        strike_zone_bottom = batter_top + (batter_bottom - batter_top) * 0.7  # Change from 0.8 to 0.7
        strike_zone_x_min = plate_bbox[0] + 10  # Narrow the width
        strike_zone_x_max = plate_bbox[2] - 10  # Narrow the width

    # Draw Strike Zone
    cv2.rectangle(frame, (int(strike_zone_x_min), int(strike_zone_top)),
                  (int(strike_zone_x_max), int(strike_zone_bottom)), (255, 0, 0), 2)  # Blue for Strike Zone
    # Check if the ball is a strike or ball
    if ball_bbox and batter_bbox and plate_bbox:
        if (strike_zone_x_min <= ball_center_x <= strike_zone_x_max and
            strike_zone_top <= ball_center_y <= strike_zone_bottom):
            result = "Strike!"
            color = (0, 255, 0)  # Green for Strike
        else:
            result = "Ball!"
            color = (0, 0, 255)  # Red for Ball

        # Display result
        cv2.putText(frame, result, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2)
        print(result)
        print(result)
        print(result)
        print(result)
        print(result)

    # Write frame to output video file
    out.write(frame)

cap.release()
out.release()

print(f"Video saved as {output_path}")
# Out:
# 0: 320x544 2 batters, 1 home plate, 87.8ms
# Speed: 8.1ms preprocess, 87.8ms inference, 362.8ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 29.6ms
# Speed: 1.6ms preprocess, 29.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 1 home plate, 11.3ms
# Speed: 2.7ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 1 home plate, 10.6ms
# Speed: 1.5ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 1 home plate, 10.5ms
# Speed: 2.8ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 1 home plate, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 1 home plate, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 1 home plate, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 1 home plate, 10.8ms
# Speed: 1.9ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 11.2ms
# Speed: 2.1ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 1 home plate, 10.3ms
# Speed: 1.7ms preprocess, 10.3ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 9.3ms
# Speed: 1.3ms preprocess, 9.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 1 home plate, 9.1ms
# Speed: 1.6ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.6ms
# Speed: 1.3ms preprocess, 8.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 1 home plate, 8.7ms
# Speed: 1.4ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.9ms
# Speed: 1.5ms preprocess, 8.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 1 home plate, 9.0ms
# Speed: 1.4ms preprocess, 9.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.8ms
# Speed: 1.3ms preprocess, 8.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 1 home plate, 9.1ms
# Speed: 1.5ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.8ms
# Speed: 1.3ms preprocess, 8.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 1 home plate, 8.7ms
# Speed: 1.6ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.6ms
# Speed: 1.3ms preprocess, 8.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 1 home plate, 9.4ms
# Speed: 1.5ms preprocess, 9.4ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.9ms
# Speed: 1.5ms preprocess, 8.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 2 home plates, 8.8ms
# Speed: 1.3ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.9ms
# Speed: 1.4ms preprocess, 8.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 2 home plates, 8.8ms
# Speed: 1.3ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.7ms
# Speed: 1.4ms preprocess, 8.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 2 home plates, 8.9ms
# Speed: 1.5ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.6ms
# Speed: 1.5ms preprocess, 8.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 2 home plates, 8.8ms
# Speed: 1.3ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.5ms
# Speed: 1.3ms preprocess, 8.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 2 home plates, 8.6ms
# Speed: 1.4ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.9ms
# Speed: 1.4ms preprocess, 8.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 2 home plates, 8.6ms
# Speed: 1.6ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.6ms
# Speed: 1.3ms preprocess, 8.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 2 home plates, 8.6ms
# Speed: 1.3ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.6ms
# Speed: 1.3ms preprocess, 8.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 2 home plates, 8.7ms
# Speed: 1.4ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.6ms
# Speed: 1.3ms preprocess, 8.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 2 home plates, 8.7ms
# Speed: 1.5ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.8ms
# Speed: 1.3ms preprocess, 8.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 2 home plates, 8.8ms
# Speed: 1.4ms preprocess, 8.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 9.1ms
# Speed: 1.4ms preprocess, 9.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 2 home plates, 9.3ms
# Speed: 1.5ms preprocess, 9.3ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 9.4ms
# Speed: 1.5ms preprocess, 9.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 2 home plates, 9.4ms
# Speed: 1.5ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.7ms
# Speed: 1.3ms preprocess, 8.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 2 home plates, 8.8ms
# Speed: 1.3ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.6ms
# Speed: 1.3ms preprocess, 8.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 1 home plate, 9.0ms
# Speed: 1.4ms preprocess, 9.0ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.8ms
# Speed: 1.4ms preprocess, 8.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 1 home plate, 8.8ms
# Speed: 1.3ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.6ms
# Speed: 1.3ms preprocess, 8.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 1 home plate, 8.6ms
# Speed: 1.3ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.5ms
# Speed: 1.4ms preprocess, 8.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 1 home plate, 9.1ms
# Speed: 1.6ms preprocess, 9.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.7ms
# Speed: 1.3ms preprocess, 8.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 1 home plate, 8.7ms
# Speed: 1.4ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.6ms
# Speed: 1.3ms preprocess, 8.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 1 home plate, 8.6ms
# Speed: 1.5ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.8ms
# Speed: 1.4ms preprocess, 8.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 2 home plates, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 2 home plates, 10.6ms
# Speed: 1.5ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 2 home plates, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.5ms
# Speed: 1.5ms preprocess, 10.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 2 batters, 2 home plates, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 2 home plates, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 2 home plates, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.1ms
# Speed: 1.4ms preprocess, 10.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 2 home plates, 10.2ms
# Speed: 1.4ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 2 home plates, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 2 home plates, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 2 home plates, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 2 home plates, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 2 home plates, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 1 home plate, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 1 home plate, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 1 home plate, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 2 home plates, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 2 home plates, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 3 home plates, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 1 home plate, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 2 home plates, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 baseball, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 544)
# Strike!
# Strike!
# Strike!
# Strike!
# Strike!
#
# 0: 320x544 1 batter, 1 home plate, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 baseball, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 544)
# Ball!
# Ball!
# Ball!
# Ball!
# Ball!
#
# 0: 320x544 1 batter, 1 home plate, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 1 home plate, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 1 home plate, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 1 home plate, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.7ms
# Speed: 1.5ms preprocess, 10.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 1 home plate, 10.8ms
# Speed: 1.5ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 12.4ms
# Speed: 1.5ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 1 home plate, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 1 home plate, 8.9ms
# Speed: 1.4ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 baseball, 8.7ms
# Speed: 1.3ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 8.7ms
# Speed: 1.5ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 baseball, 8.8ms
# Speed: 1.3ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 8.9ms
# Speed: 1.4ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.8ms
# Speed: 1.4ms preprocess, 8.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 9.1ms
# Speed: 1.3ms preprocess, 9.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.6ms
# Speed: 1.2ms preprocess, 8.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 8.6ms
# Speed: 1.3ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.9ms
# Speed: 1.3ms preprocess, 8.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 8.9ms
# Speed: 1.4ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 baseball, 8.8ms
# Speed: 1.4ms preprocess, 8.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 1 batter, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 544)
#
# 0: 320x544 (no detections), 8.7ms
# Speed: 1.4ms preprocess, 8.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 544)
# Video saved as output.mp4
